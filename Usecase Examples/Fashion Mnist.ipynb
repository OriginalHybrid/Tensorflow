# %% [markdown]
# # Fashion Mnist

# %%
import tensorflow as tf
print(tf.__version__)
import os
# os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'

mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
print(training_images.shape)
print(training_labels.shape)
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0

test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=10)
test_loss = model.evaluate(test_images, test_labels)
print(test_loss)
# Out:
# 2.7.0
# (60000, 28, 28)
# (60000,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 122,922
# Trainable params: 122,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.4671 - accuracy: 0.8297
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3149 - accuracy: 0.8843
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2707 - accuracy: 0.9006
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2418 - accuracy: 0.9106
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2143 - accuracy: 0.9200
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1970 - accuracy: 0.9268
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1771 - accuracy: 0.9338
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1603 - accuracy: 0.9402
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1462 - accuracy: 0.9448
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1336 - accuracy: 0.9502
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.9112
# [0.2704973816871643, 0.9111999869346619]

# %%
tf.keras.backend.clear_session()
tf.compat.v1.reset_default_graph()

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=10)
test_loss = model.evaluate(test_images, test_labels)
print(test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 32)          0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 128)               102528
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 122,922
# Trainable params: 122,922
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5101 - accuracy: 0.8121
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3525 - accuracy: 0.8694
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3078 - accuracy: 0.8849
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2791 - accuracy: 0.8961
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2574 - accuracy: 0.9042
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2451 - accuracy: 0.9080
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2342 - accuracy: 0.9118
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2232 - accuracy: 0.9162
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2151 - accuracy: 0.9194
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2050 - accuracy: 0.9219
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2414 - accuracy: 0.9137
# [0.24135629832744598, 0.9136999845504761]

# %%
tf.keras.backend.clear_session()
tf.compat.v1.reset_default_graph()

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=10)
test_loss = model.evaluate(test_images, test_labels)
print(test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 32)        18464
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 32)          9248
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 32)          0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 132,234
# Trainable params: 132,234
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5028 - accuracy: 0.8149
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3207 - accuracy: 0.8820
# Epoch 3/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.2812 - accuracy: 0.8968
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2582 - accuracy: 0.9047
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2401 - accuracy: 0.9115
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2252 - accuracy: 0.9165
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2132 - accuracy: 0.9208
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2036 - accuracy: 0.9244
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1979 - accuracy: 0.9261
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1875 - accuracy: 0.9301: 1s - loss: 0.1
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2197 - accuracy: 0.9210
# [0.2197001427412033, 0.9210000038146973]
